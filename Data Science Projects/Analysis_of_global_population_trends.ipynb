# %% [markdown]
# # import library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load data

# %%
df = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_533472.csv', skiprows=4)
df = df.drop('Unnamed: 69', axis=1) # Drop the empty column
df = df.dropna(subset=['2024']) # Drop rows with missing values in '2024' column
display(df.head())
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
with open('/content/API_SP.POP.TOTL_DS2_en_csv_v2_533472.csv', 'r') as f:
    for i in range(10):
        print(f.readline())
# Out:
# ﻿"Data Source","World Development Indicators",
#
#
#
# "Last Updated Date","2025-07-01",
#
#
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024",
#
# ...

# %% [markdown]
# # Data analyse

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['2024'], bins=30, kde=True)
plt.title('Distribution of Population in 2024')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Population distribution analysis for another year

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['2000'], bins=30, kde=True)
plt.title('Distribution of Population in 2000')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Population distribution analysis by region

# %%
display(df['Country Name'].unique())
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
regional_indicators = [
    'Africa Eastern and Southern', 'Africa Western and Central', 'Arab World',
    'Central Europe and the Baltics', 'East Asia & Pacific (excluding high income)',
    'Early-demographic dividend', 'East Asia & Pacific', 'Europe & Central Asia (excluding high income)',
    'Europe & Central Asia', 'Euro area', 'European Union',
    'Fragile and conflict affected situations', 'High income',
    'Heavily indebted poor countries (HIPC)', 'IBRD only', 'IDA & IBRD total', 'IDA total', 'IDA blend',
    'IDA only', 'Latin America & Caribbean (excluding high income)', 'Latin America & Caribbean',
    'Least developed countries: UN classification', 'Low income', 'Lower middle income',
    'Low & middle income', 'Late-demographic dividend',
    'Middle East, North Africa, Afghanistan & Pakistan', 'Middle income',
    'Middle East, North Africa, Afghanistan & Pakistan (excluding high income)',
    'North America', 'OECD members', 'Other small states', 'Pacific island small states',
    'Pre-demographic dividend', 'Post-demographic dividend', 'South Asia',
    'Sub-Saharan Africa (excluding high income)', 'South Sudan', 'Sub-Saharan Africa',
    'Small states'
]

df_regions = df[df['Country Name'].isin(regional_indicators)]

# Group by 'Country Name' (which are regions in this filtered df) and sum the '2024' population
regional_population_2024 = df_regions.groupby('Country Name')['2024'].sum().sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(15, 8))
regional_population_2024.plot(kind='bar')
plt.title('Total Population by Region in 2024')
plt.xlabel('Region')
plt.ylabel('Total Population')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Population change analysis

# %%
country_name = 'Egypt, Arab Rep.'
egypt_data = df[df['Country Name'] == country_name]

years = [str(year) for year in range(1960, 2025)]
population_data = egypt_data[years].iloc[0]

plt.figure(figsize=(12, 6))
plt.plot(years, population_data)
plt.title(f'Population Change in {country_name} Over the Years')
plt.xlabel('Years')
plt.ylabel('Population')
plt.xticks(years[::5], rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   A histogram for the population distribution in the year 2000 was successfully generated, visualizing the frequency of different population ranges in that year.
# *   A bar chart was successfully created illustrating the total population for various regional and economic groupings in 2024. This chart showed the relative population sizes of these aggregated areas.
# *   A line plot was successfully generated showing the population change for Egypt from 1960 to 2024, indicating a general trend of population growth over this period.
#
# ### Insights or Next Steps
#
# *   Compare the histograms for 2000 and 2024 more formally to identify specific shifts in population distribution patterns.
# *   Analyze the population trends for other individual countries or groups of countries to compare their growth patterns with that of Egypt and the regional aggregates.
